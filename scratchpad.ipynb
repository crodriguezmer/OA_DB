# %%
import requests
import mysql.connector
from datetime import datetime
from itertools import compress
import numpy as np
import urllib.parse


def fetch_query_results(cur, numrecords=10):
    result = []
    if type(numrecords) == int:
        i = 0
        for row in cur:    
            if i < numrecords:
                result.append(row)
                i += 1
    elif numrecords == 'all':
        for row in cur:    
            result.append(row)
    return result



def retrieve_journals():    
    cnx = mysql.connector.connect(user='root', password='CarM5500',
                              host='localhost',
                              database='OA')
    curA = cnx.cursor()
    retrieve_journals_query = '''select name from doaj_journals order by doaj_seal desc, name asc;'''
    curA.execute(retrieve_journals_query)
    return fetch_query_results(curA, 'all')



def retrieve_article_bib_details(bibjson):
    try:
        pages = bibjson['start_page'] + '-' + bibjson['end_page']
    except:
        pages = ''
    try:
        title = str(bibjson['title'])
    except:
        title = ''
    try:
        year = bibjson['year']
    except:
        year = ''
    try:
        journal_title = bibjson['journal']['title']
    except:
        journal_title = ''
    try:
        journal_number = bibjson['journal']['number']
    except:
        journal_number = ''
    try:
        journal_volume = bibjson['journal']['volume']
    except:
        journal_volume = ''
    try:
        journal_publisher = bibjson['journal']['publisher']
    except:
        journal_publisher = ''
    try:
        link = bibjson['link'][0]['url']
    except:
        link = ''
    try:
        link_type = bibjson['link'][0]['type']
    except:
        link_type = ''
        
    authors = []
    try:
        for author in bibjson['author']:
            authors.append( author['name'] )
    except:
        pass
        
    subjects = []
    try:
        for subject in bibjson['subject']:
            subjects.append( subject['term'] )
    except:
        pass    

    return  {'title':title, 'pages':pages, 'year':year, 
             'journal_title':journal_title, 'journal_publisher': journal_publisher,
             'authors':str(authors), 'subjects':str(subjects)}



def retrieve_article_details(article):
    doaj_created_date = datetime.strptime( article['created_date'], '%Y-%m-%dT%H:%M:%SZ').strftime('%Y-%m-%d %H:%M:%S')
    doaj_last_updated = datetime.strptime( article['last_updated'], '%Y-%m-%dT%H:%M:%SZ').strftime('%Y-%m-%d %H:%M:%S')
    article_details = {'id':article['id'], 
                       'doaj_created_date':doaj_created_date,
                      'doaj_last_updated':doaj_last_updated}
    return { **article_details, **retrieve_article_bib_details(article['bibjson']) }


#########
def get_page_articles(page):
    try:
        print( 'Retrieving articles from page %s' % page['page'] )
        page_articles = []
        for article in page['results']:
            page_articles.append( retrieve_article_details( article ) )
        return page_articles
    except:
        pass

    
def get_data(journal_url):
    page = requests.get(journal_url).json()
    articles = get_page_articles(page)
    more_pages = True
    while more_pages:
        try:
            page = requests.get( page['next'] ).json()
            articles.extend( get_page_articles(page) )
        except:
            more_pages = False
    return articles



def write_articles_to_doaj_articles_table(articles):
    
    cnx = mysql.connector.connect(user='root', password='CarM5500',
                              host='localhost', charset = 'utf8mb4', collation='utf8mb4_unicode_ci',
                              database='OA')
    for article in articles:
        column_names        = article.keys()
        column_non_missing  = [] 
        for value in article.values():
            column_non_missing.append( value != '')

        non_missing_columns = list(compress(column_names, column_non_missing))
        non_missing_data    = list(compress(article.values(), column_non_missing))

        # concatenate into single string all the column names
        col_name_tuple = "("
        for column in non_missing_columns:
            col_name_tuple += column + ', '
        col_name_tuple = col_name_tuple[:-2] + ')'

        query = '''
        insert into doaj_articles %s
        values %s
        ''' % ( col_name_tuple, str(tuple(non_missing_data)) )

        cnx.cmd_query(query)
        cnx.commit()
    cnx.close()
    
    
    
def create_doaj_articles_table():
    query = '''
    create table doaj_articles
    (
    # %s varchar(300) CHARACTER SET utf8,

    # %s DATETIME,
    # %s DATETIME,

    # %s text CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci,

    # %s varchar(300) CHARACTER SET utf8,
    # %s varchar(300) CHARACTER SET utf8,
    # %s varchar(300) CHARACTER SET utf8,
    # %s varchar(300) CHARACTER SET utf8,

    # %s text CHARACTER SET utf8,
    # %s text CHARACTER SET utf8
    );
    ''' % tuple(['id', 'doaj_created_date', 'doaj_last_updated', 
                'title', 'pages', 'year', 'journal_title', 'journal_publisher', 
                'authors', 'subjects'])

    cnx = mysql.connector.connect(user='root', password='CarM5500',
                              host='localhost', charset = 'utf8mb4', collation='utf8mb4_unicode_ci',
                              database='OA')
    cnx.cmd_query('drop table if exists doaj_articles;')
    cnx.cmd_query(query)
    cnx.commit();
    cnx.close();



# create_doaj_articles_table()
journals = retrieve_journals()

for journal in journals[3438]:
    print('Working on %s' % journal)
    journal_url = 'https://doaj.org/api/v1/search/articles/journal:"%s"' % urllib.parse.quote_plus(journal[0])
    articles = get_data( journal_url )
    write_articles_to_doaj_articles_table(articles)
# Out:
# Working on Educate~
# Retrieving articles from page 1
# Retrieving articles from page 2
# Retrieving articles from page 3
# Retrieving articles from page 4
# Retrieving articles from page 5
# Retrieving articles from page 6
# Retrieving articles from page 7
# Retrieving articles from page 8
# Retrieving articles from page 9
# Retrieving articles from page 10
# Retrieving articles from page 11
# Retrieving articles from page 12
# Retrieving articles from page 13
# Retrieving articles from page 14
# Retrieving articles from page 15
# Retrieving articles from page 16
# Retrieving articles from page 17
# Retrieving articles from page 18
# Retrieving articles from page 19
# Retrieving articles from page 20
# Retrieving articles from page 21
# Retrieving articles from page 22
# Retrieving articles from page 23
# Retrieving articles from page 24
# Retrieving articles from page 25
# Retrieving articles from page 26
# Retrieving articles from page 27
# Retrieving articles from page 28
# Retrieving articles from page 29
# Retrieving articles from page 30
# Retrieving articles from page 31
# Retrieving articles from page 32
# Retrieving articles from page 33
# Retrieving articles from page 34
# Retrieving articles from page 35
# Retrieving articles from page 36
# Retrieving articles from page 37
# Retrieving articles from page 38
# Retrieving articles from page 39
# Retrieving articles from page 40
# Retrieving articles from page 41
# Retrieving articles from page 42
# Retrieving articles from page 43
# Retrieving articles from page 44
# Retrieving articles from page 45
# Retrieving articles from page 46
# Retrieving articles from page 47
# Retrieving articles from page 48
# Retrieving articles from page 49
# Retrieving articles from page 50
# Retrieving articles from page 51
# Retrieving articles from page 52
# Retrieving articles from page 53
# Retrieving articles from page 54
# Retrieving articles from page 55
# Retrieving articles from page 56
# Retrieving articles from page 57
# Retrieving articles from page 58
# Retrieving articles from page 59
# Retrieving articles from page 60
# Retrieving articles from page 61
# Retrieving articles from page 62
# Retrieving articles from page 63
# Retrieving articles from page 64
# Retrieving articles from page 65
# Retrieving articles from page 66
# Retrieving articles from page 67
# Retrieving articles from page 68
# Retrieving articles from page 69
# Retrieving articles from page 70
# Retrieving articles from page 71
# Retrieving articles from page 72
# Retrieving articles from page 73
# Retrieving articles from page 74
# Retrieving articles from page 75
# Retrieving articles from page 76
# Retrieving articles from page 77
# Retrieving articles from page 78
# Retrieving articles from page 79
# Retrieving articles from page 80
# Retrieving articles from page 81
# Retrieving articles from page 82
# Retrieving articles from page 83
# Retrieving articles from page 84
# Retrieving articles from page 85
# Retrieving articles from page 86
# Retrieving articles from page 87
# Retrieving articles from page 88
# Retrieving articles from page 89
# Retrieving articles from page 90
# Retrieving articles from page 91
# Retrieving articles from page 92
# Retrieving articles from page 93
# Retrieving articles from page 94
# Retrieving articles from page 95
# Retrieving articles from page 96
# Retrieving articles from page 97
# Retrieving articles from page 98
# Retrieving articles from page 99
# Retrieving articles from page 100
# Retrieving articles from page 101
# Retrieving articles from page 102
# Retrieving articles from page 103
# Retrieving articles from page 104
# Retrieving articles from page 105
# Retrieving articles from page 106
# Retrieving articles from page 107
# Retrieving articles from page 108
# Retrieving articles from page 109
# Retrieving articles from page 110
# Retrieving articles from page 111
# Retrieving articles from page 112
# Retrieving articles from page 113
# Retrieving articles from page 114
# Retrieving articles from page 115
# Retrieving articles from page 116
# Retrieving articles from page 117
# Retrieving articles from page 118
# Retrieving articles from page 119
# Retrieving articles from page 120
# Retrieving articles from page 121
# Retrieving articles from page 122
# Retrieving articles from page 123
# Retrieving articles from page 124
# Retrieving articles from page 125
# Retrieving articles from page 126
# Retrieving articles from page 127
# Retrieving articles from page 128
# Retrieving articles from page 129
# Retrieving articles from page 130
# Retrieving articles from page 131
# Retrieving articles from page 132
# Retrieving articles from page 133
# Retrieving articles from page 134
# Retrieving articles from page 135
# Retrieving articles from page 136
# Retrieving articles from page 137
# Retrieving articles from page 138
# Retrieving articles from page 139
# Retrieving articles from page 140
# Retrieving articles from page 141
# Retrieving articles from page 142
# Retrieving articles from page 143
# Retrieving articles from page 144
# Retrieving articles from page 145
# Retrieving articles from page 146
# Retrieving articles from page 147
# Retrieving articles from page 148
# Retrieving articles from page 149
# Retrieving articles from page 150
# Retrieving articles from page 151
# Retrieving articles from page 152
# Retrieving articles from page 153
# Retrieving articles from page 154
# Retrieving articles from page 155
# Retrieving articles from page 156
# Retrieving articles from page 157
# Retrieving articles from page 158
# Retrieving articles from page 159
# Retrieving articles from page 160
# Retrieving articles from page 161
# Retrieving articles from page 162
# Retrieving articles from page 163
# Retrieving articles from page 164
# Retrieving articles from page 165
# Retrieving articles from page 166
# Retrieving articles from page 167
# Retrieving articles from page 168
# Retrieving articles from page 169
# Retrieving articles from page 170
# Retrieving articles from page 171
# Retrieving articles from page 172
# Retrieving articles from page 173
# Retrieving articles from page 174
# Retrieving articles from page 175
# Retrieving articles from page 176
# Retrieving articles from page 177
# Retrieving articles from page 178
# Retrieving articles from page 179
# Retrieving articles from page 180
# Retrieving articles from page 181
# Retrieving articles from page 182
# Retrieving articles from page 183
# Retrieving articles from page 184
# Retrieving articles from page 185
# Retrieving articles from page 186
# Retrieving articles from page 187
# Retrieving articles from page 188
# Retrieving articles from page 189
# Retrieving articles from page 190
# Retrieving articles from page 191
# Retrieving articles from page 192
# Retrieving articles from page 193
# Retrieving articles from page 194
# Retrieving articles from page 195
# Retrieving articles from page 196
# Retrieving articles from page 197
# Retrieving articles from page 198
# Retrieving articles from page 199
# Retrieving articles from page 200
# Retrieving articles from page 201
# Retrieving articles from page 202
# Retrieving articles from page 203
# Retrieving articles from page 204
# Retrieving articles from page 205
# Retrieving articles from page 206
# Retrieving articles from page 207
# Retrieving articles from page 208
# Retrieving articles from page 209
# Retrieving articles from page 210
# Retrieving articles from page 211
# Retrieving articles from page 212
# Retrieving articles from page 213
# Retrieving articles from page 214
# Retrieving articles from page 215
# Retrieving articles from page 216
# Retrieving articles from page 217
# Retrieving articles from page 218
# Retrieving articles from page 219
# Retrieving articles from page 220
# Retrieving articles from page 221
# Retrieving articles from page 222
# Retrieving articles from page 223
# Retrieving articles from page 224
# Retrieving articles from page 225
# Retrieving articles from page 226
# Retrieving articles from page 227
# Retrieving articles from page 228
# Retrieving articles from page 229
# Retrieving articles from page 230
# Retrieving articles from page 231
# Retrieving articles from page 232
# Retrieving articles from page 233
# Retrieving articles from page 234
# Retrieving articles from page 235
# Retrieving articles from page 236
# Retrieving articles from page 237
# Retrieving articles from page 238
# Retrieving articles from page 239
# Retrieving articles from page 240
# Retrieving articles from page 241
# Retrieving articles from page 242
# Retrieving articles from page 243
# Retrieving articles from page 244
# Retrieving articles from page 245
# Retrieving articles from page 246
# Retrieving articles from page 247
# Retrieving articles from page 248
# Retrieving articles from page 249
# Retrieving articles from page 250
# Retrieving articles from page 251
# Retrieving articles from page 252
# Retrieving articles from page 253
# Retrieving articles from page 254
# Retrieving articles from page 255
# Retrieving articles from page 256
# Retrieving articles from page 257
# Retrieving articles from page 258
# Retrieving articles from page 259
# Retrieving articles from page 260
# Retrieving articles from page 261
# Retrieving articles from page 262
# Retrieving articles from page 263
# Retrieving articles from page 264
# Retrieving articles from page 265
# Retrieving articles from page 266
# Retrieving articles from page 267
# Retrieving articles from page 268
# Retrieving articles from page 269
# Retrieving articles from page 270
# Retrieving articles from page 271
# Retrieving articles from page 272
# Retrieving articles from page 273
# Retrieving articles from page 274
# Retrieving articles from page 275
# Retrieving articles from page 276
# Retrieving articles from page 277
# Retrieving articles from page 278
# Retrieving articles from page 279
# Retrieving articles from page 280
# Retrieving articles from page 281
# Retrieving articles from page 282
# Retrieving articles from page 283
# Retrieving articles from page 284
# Retrieving articles from page 285
# Retrieving articles from page 286
# Retrieving articles from page 287
# Retrieving articles from page 288
# Retrieving articles from page 289
# Retrieving articles from page 290
# Retrieving articles from page 291
# Retrieving articles from page 292
# Retrieving articles from page 293
# Retrieving articles from page 294
# Retrieving articles from page 295
# Retrieving articles from page 296
# Retrieving articles from page 297
# Retrieving articles from page 298
# Retrieving articles from page 299
# Retrieving articles from page 300
# Retrieving articles from page 301
# Retrieving articles from page 302
# Retrieving articles from page 303
# Retrieving articles from page 304
# Retrieving articles from page 305
# Retrieving articles from page 306
# Retrieving articles from page 307
# Retrieving articles from page 308
# Retrieving articles from page 309
# Retrieving articles from page 310
# Retrieving articles from page 311
# Retrieving articles from page 312
# Retrieving articles from page 313
# Retrieving articles from page 314
# Retrieving articles from page 315
# Retrieving articles from page 316
# Retrieving articles from page 317
# Retrieving articles from page 318
# Retrieving articles from page 319
# Retrieving articles from page 320
# Retrieving articles from page 321
# Retrieving articles from page 322
# Retrieving articles from page 323
# Retrieving articles from page 324
# Retrieving articles from page 325
# Retrieving articles from page 326
# Retrieving articles from page 327
# Retrieving articles from page 328
# Retrieving articles from page 329
# Retrieving articles from page 330
# Retrieving articles from page 331
# Retrieving articles from page 332
# Retrieving articles from page 333
# Retrieving articles from page 334
# Retrieving articles from page 335
# Retrieving articles from page 336
# Retrieving articles from page 337
# Retrieving articles from page 338
# Retrieving articles from page 339
# Retrieving articles from page 340
# Retrieving articles from page 341
# Retrieving articles from page 342
# Retrieving articles from page 343
# Retrieving articles from page 344
# Retrieving articles from page 345
# Retrieving articles from page 346
# Retrieving articles from page 347
# Retrieving articles from page 348
# Retrieving articles from page 349
# Retrieving articles from page 350
# Retrieving articles from page 351
# Retrieving articles from page 352
# Retrieving articles from page 353
# Retrieving articles from page 354
# Retrieving articles from page 355
# Retrieving articles from page 356
# Retrieving articles from page 357
# Retrieving articles from page 358
# Retrieving articles from page 359
# Retrieving articles from page 360
# Retrieving articles from page 361
# Retrieving articles from page 362
# Retrieving articles from page 363
# Retrieving articles from page 364
# Retrieving articles from page 365
# Retrieving articles from page 366
# Retrieving articles from page 367
# Retrieving articles from page 368
# Retrieving articles from page 369
# Retrieving articles from page 370
# Retrieving articles from page 371
# Retrieving articles from page 372
# Retrieving articles from page 373
# Retrieving articles from page 374
# Retrieving articles from page 375
# Retrieving articles from page 376
# Retrieving articles from page 377
# Retrieving articles from page 378
# Retrieving articles from page 379
# Retrieving articles from page 380
# Retrieving articles from page 381
# Retrieving articles from page 382
# Retrieving articles from page 383
# Retrieving articles from page 384
# Retrieving articles from page 385
# Retrieving articles from page 386
# Retrieving articles from page 387
# Retrieving articles from page 388
# Retrieving articles from page 389
# Retrieving articles from page 390
# Retrieving articles from page 391
# Retrieving articles from page 392
# Retrieving articles from page 393
# Retrieving articles from page 394
# Retrieving articles from page 395
# Retrieving articles from page 396
# Retrieving articles from page 397
# Retrieving articles from page 398
# Retrieving articles from page 399
# Retrieving articles from page 400
# Retrieving articles from page 401
# Retrieving articles from page 402
# Retrieving articles from page 403
# Retrieving articles from page 404
# Retrieving articles from page 405
# Retrieving articles from page 406
# Retrieving articles from page 407
# Retrieving articles from page 408
# Retrieving articles from page 409
# Retrieving articles from page 410
# Retrieving articles from page 411
# Retrieving articles from page 412
# Retrieving articles from page 413
# Retrieving articles from page 414
# Retrieving articles from page 415
# Retrieving articles from page 416
# Retrieving articles from page 417
# Retrieving articles from page 418
# Retrieving articles from page 419
# Retrieving articles from page 420
# Retrieving articles from page 421
# Retrieving articles from page 422
# Retrieving articles from page 423
# Retrieving articles from page 424
# Retrieving articles from page 425
# Retrieving articles from page 426
# Retrieving articles from page 427
# Retrieving articles from page 428
# Retrieving articles from page 429
# Retrieving articles from page 430
# Retrieving articles from page 431
# Retrieving articles from page 432
# Retrieving articles from page 433
# Retrieving articles from page 434
# Retrieving articles from page 435
# Retrieving articles from page 436
# Retrieving articles from page 437
# Retrieving articles from page 438
# Retrieving articles from page 439
# Retrieving articles from page 440
# Retrieving articles from page 441
# Retrieving articles from page 442
# Retrieving articles from page 443
# Retrieving articles from page 444
# Retrieving articles from page 445
# Retrieving articles from page 446
# Retrieving articles from page 447
# Retrieving articles from page 448
# Retrieving articles from page 449
# Retrieving articles from page 450
# Retrieving articles from page 451
# Retrieving articles from page 452
# Retrieving articles from page 453
# Retrieving articles from page 454
# Retrieving articles from page 455
# Retrieving articles from page 456
# Retrieving articles from page 457
# Retrieving articles from page 458
# Retrieving articles from page 459
# Retrieving articles from page 460
# Retrieving articles from page 461
# Retrieving articles from page 462
# Retrieving articles from page 463
# Retrieving articles from page 464
# Retrieving articles from page 465
# Retrieving articles from page 466
# Retrieving articles from page 467
# Retrieving articles from page 468
# Retrieving articles from page 469
# Retrieving articles from page 470
# Retrieving articles from page 471
# Retrieving articles from page 472
# Retrieving articles from page 473
# Retrieving articles from page 474
# Retrieving articles from page 475
# Retrieving articles from page 476
# Retrieving articles from page 477
# Retrieving articles from page 478
# Retrieving articles from page 479
# Retrieving articles from page 480
# Retrieving articles from page 481
# Retrieving articles from page 482
# Retrieving articles from page 483
# Retrieving articles from page 484
# Retrieving articles from page 485
# Retrieving articles from page 486
# Retrieving articles from page 487
# Retrieving articles from page 488
# Retrieving articles from page 489
# Retrieving articles from page 490
# Retrieving articles from page 491
# Retrieving articles from page 492
# Retrieving articles from page 493
# Retrieving articles from page 494
# Retrieving articles from page 495
# Retrieving articles from page 496
# Retrieving articles from page 497
# Retrieving articles from page 498
# Retrieving articles from page 499
# Retrieving articles from page 500
# Retrieving articles from page 501
# Retrieving articles from page 502
# Retrieving articles from page 503
# Retrieving articles from page 504
# Retrieving articles from page 505
# Retrieving articles from page 506
# Retrieving articles from page 507
# Retrieving articles from page 508
# Retrieving articles from page 509
# Retrieving articles from page 510
# Retrieving articles from page 511
# Retrieving articles from page 512
# Retrieving articles from page 513
# Retrieving articles from page 514
# Retrieving articles from page 515
# Retrieving articles from page 516
# Retrieving articles from page 517
# Retrieving articles from page 518
# Retrieving articles from page 519
# Retrieving articles from page 520
# Retrieving articles from page 521
# Retrieving articles from page 522
# Retrieving articles from page 523
# Retrieving articles from page 524
# Retrieving articles from page 525
# Retrieving articles from page 526
# Retrieving articles from page 527
# Retrieving articles from page 528
# Retrieving articles from page 529
# Retrieving articles from page 530
# Retrieving articles from page 531
# Retrieving articles from page 532
# Retrieving articles from page 533
# Retrieving articles from page 534
# Retrieving articles from page 535
# Retrieving articles from page 536
# Retrieving articles from page 537
# Retrieving articles from page 538
# Retrieving articles from page 539
# Retrieving articles from page 540
# Retrieving articles from page 541
# Retrieving articles from page 542
# Retrieving articles from page 543
# Retrieving articles from page 544
# Retrieving articles from page 545
# Retrieving articles from page 546
# Retrieving articles from page 547
# Retrieving articles from page 548
# Retrieving articles from page 549
# Retrieving articles from page 550
# Retrieving articles from page 551
# Retrieving articles from page 552
# Retrieving articles from page 553
# Retrieving articles from page 554
# Retrieving articles from page 555
# Retrieving articles from page 556
# Retrieving articles from page 557
# Retrieving articles from page 558
# Retrieving articles from page 559
# Retrieving articles from page 560
# Retrieving articles from page 561
# Retrieving articles from page 562
# Retrieving articles from page 563
# Retrieving articles from page 564
# Retrieving articles from page 565
# Retrieving articles from page 566
# Retrieving articles from page 567
# Retrieving articles from page 568
# Retrieving articles from page 569
# Retrieving articles from page 570
# Retrieving articles from page 571
# Retrieving articles from page 572
# Retrieving articles from page 573
# Retrieving articles from page 574
# Retrieving articles from page 575
# Retrieving articles from page 576
# Retrieving articles from page 577
# Retrieving articles from page 578
# Retrieving articles from page 579
# Retrieving articles from page 580
# Retrieving articles from page 581
# Retrieving articles from page 582
# Retrieving articles from page 583
# Retrieving articles from page 584
# Retrieving articles from page 585
# Retrieving articles from page 586
# Retrieving articles from page 587
# Retrieving articles from page 588
# Retrieving articles from page 589
# Retrieving articles from page 590
# Retrieving articles from page 591
# Retrieving articles from page 592
# Retrieving articles from page 593
# Retrieving articles from page 594
# Retrieving articles from page 595
# Retrieving articles from page 596
# Retrieving articles from page 597
# Retrieving articles from page 598
# Retrieving articles from page 599
# Retrieving articles from page 600
# Retrieving articles from page 601
# Retrieving articles from page 602
# Retrieving articles from page 603
# Retrieving articles from page 604
# Retrieving articles from page 605
# Retrieving articles from page 606
# Retrieving articles from page 607
# Retrieving articles from page 608
# Retrieving articles from page 609
# Retrieving articles from page 610
# Retrieving articles from page 611
# Retrieving articles from page 612
# Retrieving articles from page 613
# Retrieving articles from page 614
# Retrieving articles from page 615
# Retrieving articles from page 616
# Retrieving articles from page 617
# Retrieving articles from page 618
# Retrieving articles from page 619
# Retrieving articles from page 620
# Retrieving articles from page 621
# Retrieving articles from page 622
# Retrieving articles from page 623
# Retrieving articles from page 624
# Retrieving articles from page 625
# Retrieving articles from page 626
# Retrieving articles from page 627
# Retrieving articles from page 628
# Retrieving articles from page 629
# Retrieving articles from page 630
# Retrieving articles from page 631
# Retrieving articles from page 632
# Retrieving articles from page 633
# Retrieving articles from page 634
# Retrieving articles from page 635
# Retrieving articles from page 636
# Retrieving articles from page 637
# Retrieving articles from page 638
# Retrieving articles from page 639
# Retrieving articles from page 640
# Retrieving articles from page 641
# Retrieving articles from page 642
# Retrieving articles from page 643
# Retrieving articles from page 644
# Retrieving articles from page 645
# Retrieving articles from page 646
# Retrieving articles from page 647
# Retrieving articles from page 648
# Retrieving articles from page 649
# Retrieving articles from page 650
# Retrieving articles from page 651
# Retrieving articles from page 652
# Retrieving articles from page 653
# Retrieving articles from page 654
# Retrieving articles from page 655
# Retrieving articles from page 656
# Retrieving articles from page 657
# Retrieving articles from page 658
# Retrieving articles from page 659
# Retrieving articles from page 660
# Retrieving articles from page 661
# Retrieving articles from page 662
# Retrieving articles from page 663
# Retrieving articles from page 664
# Retrieving articles from page 665
# Retrieving articles from page 666
# Retrieving articles from page 667
# Retrieving articles from page 668
# Retrieving articles from page 669
# Retrieving articles from page 670
# Retrieving articles from page 671
# Retrieving articles from page 672
# Retrieving articles from page 673
# Retrieving articles from page 674
# Retrieving articles from page 675
# Retrieving articles from page 676
# Retrieving articles from page 677
# Retrieving articles from page 678
# Retrieving articles from page 679
# Retrieving articles from page 680
# Retrieving articles from page 681
# Retrieving articles from page 682
# Retrieving articles from page 683
# Retrieving articles from page 684
# Retrieving articles from page 685
# Retrieving articles from page 686
# Retrieving articles from page 687
# Retrieving articles from page 688
# Retrieving articles from page 689
# Retrieving articles from page 690
# Retrieving articles from page 691
# Retrieving articles from page 692
# Retrieving articles from page 693
# Retrieving articles from page 694
# Retrieving articles from page 695
# Retrieving articles from page 696
# Retrieving articles from page 697
# Retrieving articles from page 698
# Retrieving articles from page 699
# Retrieving articles from page 700
# Retrieving articles from page 701
# Retrieving articles from page 702
# Retrieving articles from page 703
# Retrieving articles from page 704
# Retrieving articles from page 705
# Retrieving articles from page 706
# Retrieving articles from page 707
# Retrieving articles from page 708
# Retrieving articles from page 709
# Retrieving articles from page 710
# Retrieving articles from page 711
# Retrieving articles from page 712
# Retrieving articles from page 713
# Retrieving articles from page 714
# Retrieving articles from page 715
# Retrieving articles from page 716
# Retrieving articles from page 717
# Retrieving articles from page 718
# Retrieving articles from page 719
# Retrieving articles from page 720
# Retrieving articles from page 721
# Retrieving articles from page 722
# Retrieving articles from page 723
# Retrieving articles from page 724
# Retrieving articles from page 725
# Retrieving articles from page 726
# Retrieving articles from page 727
# Retrieving articles from page 728
# Retrieving articles from page 729
# Retrieving articles from page 730
# Retrieving articles from page 731
# Retrieving articles from page 732
# Retrieving articles from page 733
# Retrieving articles from page 734
# Retrieving articles from page 735
# Retrieving articles from page 736
# Retrieving articles from page 737
# Retrieving articles from page 738
# Retrieving articles from page 739
# Retrieving articles from page 740
# Retrieving articles from page 741
# Retrieving articles from page 742
# Retrieving articles from page 743
# Retrieving articles from page 744
# Retrieving articles from page 745
# Retrieving articles from page 746
# Retrieving articles from page 747
# Retrieving articles from page 748
# Retrieving articles from page 749
# Retrieving articles from page 750
# Retrieving articles from page 751
# Retrieving articles from page 752
# Retrieving articles from page 753
# Retrieving articles from page 754
# Retrieving articles from page 755
# Retrieving articles from page 756
# Retrieving articles from page 757
# Retrieving articles from page 758
# Retrieving articles from page 759
# Retrieving articles from page 760
# Retrieving articles from page 761
# Retrieving articles from page 762
# Retrieving articles from page 763
# Retrieving articles from page 764
# Retrieving articles from page 765
# Retrieving articles from page 766
# Retrieving articles from page 767
# Retrieving articles from page 768
# Retrieving articles from page 769
# Retrieving articles from page 770
# Retrieving articles from page 771
# Retrieving articles from page 772
# Retrieving articles from page 773
# Retrieving articles from page 774
# Retrieving articles from page 775
# Retrieving articles from page 776
# Retrieving articles from page 777
# Retrieving articles from page 778
# Retrieving articles from page 779
# Retrieving articles from page 780
# Retrieving articles from page 781
# Retrieving articles from page 782
# Retrieving articles from page 783
# Retrieving articles from page 784
# Retrieving articles from page 785
# Retrieving articles from page 786
# Retrieving articles from page 787
# Retrieving articles from page 788
# Retrieving articles from page 789
# Retrieving articles from page 790
# Retrieving articles from page 791
# Retrieving articles from page 792
# Retrieving articles from page 793
# Retrieving articles from page 794
# Retrieving articles from page 795
# Retrieving articles from page 796
# Retrieving articles from page 797
# Retrieving articles from page 798
# Retrieving articles from page 799
# Retrieving articles from page 800
# Retrieving articles from page 801
# Retrieving articles from page 802
# Retrieving articles from page 803
# Retrieving articles from page 804
# Retrieving articles from page 805
# Retrieving articles from page 806
# Retrieving articles from page 807
# Retrieving articles from page 808
# Retrieving articles from page 809
# Retrieving articles from page 810
# Retrieving articles from page 811
# Retrieving articles from page 812
# Retrieving articles from page 813
# Retrieving articles from page 814
# Retrieving articles from page 815
# Retrieving articles from page 816
# Retrieving articles from page 817
# Retrieving articles from page 818
# Retrieving articles from page 819
# Retrieving articles from page 820
# Retrieving articles from page 821
# Retrieving articles from page 822
# Retrieving articles from page 823
# Retrieving articles from page 824
# Retrieving articles from page 825
# Retrieving articles from page 826
# Retrieving articles from page 827
# Retrieving articles from page 828
# Retrieving articles from page 829
# Retrieving articles from page 830
# Retrieving articles from page 831
# Retrieving articles from page 832
# Retrieving articles from page 833
# Retrieving articles from page 834
# Retrieving articles from page 835
# Retrieving articles from page 836
# Retrieving articles from page 837
# Retrieving articles from page 838
# Retrieving articles from page 839
# Retrieving articles from page 840
# Retrieving articles from page 841
# Retrieving articles from page 842
# Retrieving articles from page 843
# Retrieving articles from page 844
# Retrieving articles from page 845
# Retrieving articles from page 846
# Retrieving articles from page 847
# Retrieving articles from page 848
# Retrieving articles from page 849
# Retrieving articles from page 850
# Retrieving articles from page 851
# Retrieving articles from page 852
# Retrieving articles from page 853
# Retrieving articles from page 854
# Retrieving articles from page 855
# Retrieving articles from page 856
# Retrieving articles from page 857
# Retrieving articles from page 858
# Retrieving articles from page 859
# Retrieving articles from page 860
# Retrieving articles from page 861
# Retrieving articles from page 862
# Retrieving articles from page 863
# Retrieving articles from page 864
# Retrieving articles from page 865
# Retrieving articles from page 866
# Retrieving articles from page 867
# Retrieving articles from page 868
# Retrieving articles from page 869
# Retrieving articles from page 870
# Retrieving articles from page 871
# Retrieving articles from page 872
# Retrieving articles from page 873
# Retrieving articles from page 874
# Retrieving articles from page 875
# Retrieving articles from page 876
# Retrieving articles from page 877
# Retrieving articles from page 878
# Retrieving articles from page 879
# Retrieving articles from page 880
# Retrieving articles from page 881
# Retrieving articles from page 882
# Retrieving articles from page 883
# Retrieving articles from page 884
# Retrieving articles from page 885
# Retrieving articles from page 886
# Retrieving articles from page 887
# Retrieving articles from page 888
# Retrieving articles from page 889
# Retrieving articles from page 890
# Retrieving articles from page 891
# Retrieving articles from page 892
# Retrieving articles from page 893
# Retrieving articles from page 894
# Retrieving articles from page 895
# Retrieving articles from page 896
# Retrieving articles from page 897
# Retrieving articles from page 898
# Retrieving articles from page 899
# Retrieving articles from page 900
# Retrieving articles from page 901
# Retrieving articles from page 902
# Retrieving articles from page 903
# Retrieving articles from page 904
# Retrieving articles from page 905
# Retrieving articles from page 906
# Retrieving articles from page 907
# Retrieving articles from page 908
# Retrieving articles from page 909
# Retrieving articles from page 910
# Retrieving articles from page 911
# Retrieving articles from page 912
# Retrieving articles from page 913
# Retrieving articles from page 914
# Retrieving articles from page 915
# Retrieving articles from page 916
# Retrieving articles from page 917
# Retrieving articles from page 918
# Retrieving articles from page 919
# Retrieving articles from page 920
# Retrieving articles from page 921
# Retrieving articles from page 922
# Retrieving articles from page 923
# Retrieving articles from page 924
# Retrieving articles from page 925
# Retrieving articles from page 926
# Retrieving articles from page 927
# Retrieving articles from page 928
# Retrieving articles from page 929
# Retrieving articles from page 930
# Retrieving articles from page 931
# Retrieving articles from page 932
# Retrieving articles from page 933
# Retrieving articles from page 934
# Retrieving articles from page 935
# Retrieving articles from page 936
# Retrieving articles from page 937
# Retrieving articles from page 938
# Retrieving articles from page 939
# Retrieving articles from page 940
# Retrieving articles from page 941
# Retrieving articles from page 942
# Retrieving articles from page 943
# Retrieving articles from page 944
# Retrieving articles from page 945
# Retrieving articles from page 946
# Retrieving articles from page 947
# Retrieving articles from page 948
# Retrieving articles from page 949
# Retrieving articles from page 950
# Retrieving articles from page 951
# Retrieving articles from page 952
# Retrieving articles from page 953
# Retrieving articles from page 954
# Retrieving articles from page 955
# Retrieving articles from page 956
# Retrieving articles from page 957
# Retrieving articles from page 958
# Retrieving articles from page 959
# Retrieving articles from page 960
# Retrieving articles from page 961
# Retrieving articles from page 962
# Retrieving articles from page 963
# Retrieving articles from page 964
# Retrieving articles from page 965
# Retrieving articles from page 966
# Retrieving articles from page 967
# Retrieving articles from page 968
# Retrieving articles from page 969
# Retrieving articles from page 970
# Retrieving articles from page 971
# Retrieving articles from page 972
# Retrieving articles from page 973
# Retrieving articles from page 974
# Retrieving articles from page 975
# Retrieving articles from page 976
# Retrieving articles from page 977
# Retrieving articles from page 978
# Retrieving articles from page 979
# Retrieving articles from page 980
# Retrieving articles from page 981
# Retrieving articles from page 982
# Retrieving articles from page 983
# Retrieving articles from page 984
# Retrieving articles from page 985
# Retrieving articles from page 986
# Retrieving articles from page 987
# Retrieving articles from page 988
# Retrieving articles from page 989
# Retrieving articles from page 990
# Retrieving articles from page 991
# Retrieving articles from page 992
# Retrieving articles from page 993
# Retrieving articles from page 994
# Retrieving articles from page 995
# Retrieving articles from page 996
# Retrieving articles from page 997
# Retrieving articles from page 998
# Retrieving articles from page 999
# Retrieving articles from page 1000
# Retrieving articles from page 1001
# Retrieving articles from page 1002
# Retrieving articles from page 1003
# Retrieving articles from page 1004
# Retrieving articles from page 1005
# Retrieving articles from page 1006
# Retrieving articles from page 1007
# Retrieving articles from page 1008
# Retrieving articles from page 1009
# Retrieving articles from page 1010
# Retrieving articles from page 1011
# Retrieving articles from page 1012
# Retrieving articles from page 1013
# Retrieving articles from page 1014
# Retrieving articles from page 1015
# Retrieving articles from page 1016
# Retrieving articles from page 1017
# Retrieving articles from page 1018
# Retrieving articles from page 1019
# Retrieving articles from page 1020
# Retrieving articles from page 1021
# Retrieving articles from page 1022
# Retrieving articles from page 1023
# Retrieving articles from page 1024
# Retrieving articles from page 1025
# Retrieving articles from page 1026
# Retrieving articles from page 1027
# Retrieving articles from page 1028
# Retrieving articles from page 1029
# Retrieving articles from page 1030
# Retrieving articles from page 1031
# Retrieving articles from page 1032
# Retrieving articles from page 1033
# Retrieving articles from page 1034
# Retrieving articles from page 1035
# Retrieving articles from page 1036
# Retrieving articles from page 1037
# Retrieving articles from page 1038
# Retrieving articles from page 1039
# Retrieving articles from page 1040
# Retrieving articles from page 1041
# Retrieving articles from page 1042
# Retrieving articles from page 1043
# Retrieving articles from page 1044
# Retrieving articles from page 1045
# Retrieving articles from page 1046
# Retrieving articles from page 1047
# Retrieving articles from page 1048
# Retrieving articles from page 1049
# Retrieving articles from page 1050
# Retrieving articles from page 1051
# Retrieving articles from page 1052
# Retrieving articles from page 1053
# Retrieving articles from page 1054
# Retrieving articles from page 1055
# Retrieving articles from page 1056
# Retrieving articles from page 1057
# Retrieving articles from page 1058
# Retrieving articles from page 1059
# Retrieving articles from page 1060
# Retrieving articles from page 1061
# Retrieving articles from page 1062
# Retrieving articles from page 1063
# Retrieving articles from page 1064
# Retrieving articles from page 1065
# Retrieving articles from page 1066
# Retrieving articles from page 1067
# Retrieving articles from page 1068
# Retrieving articles from page 1069
# Retrieving articles from page 1070
# Retrieving articles from page 1071
# Retrieving articles from page 1072
# Retrieving articles from page 1073
# Retrieving articles from page 1074
# Retrieving articles from page 1075
# Retrieving articles from page 1076
# Retrieving articles from page 1077
# Retrieving articles from page 1078
# Retrieving articles from page 1079
# Retrieving articles from page 1080
# Retrieving articles from page 1081
# Retrieving articles from page 1082
# Retrieving articles from page 1083
# Retrieving articles from page 1084
# Retrieving articles from page 1085
# Retrieving articles from page 1086
# Retrieving articles from page 1087
# Retrieving articles from page 1088
# Retrieving articles from page 1089
# Retrieving articles from page 1090
# Retrieving articles from page 1091
# Retrieving articles from page 1092
# Retrieving articles from page 1093
# Retrieving articles from page 1094
# Retrieving articles from page 1095
# Retrieving articles from page 1096
# Retrieving articles from page 1097
# Retrieving articles from page 1098
# Retrieving articles from page 1099
# Retrieving articles from page 1100
# Retrieving articles from page 1101
# Retrieving articles from page 1102
# Retrieving articles from page 1103
# Retrieving articles from page 1104
# Retrieving articles from page 1105
# Retrieving articles from page 1106
# Retrieving articles from page 1107
# Retrieving articles from page 1108
# Retrieving articles from page 1109
# Retrieving articles from page 1110
# Retrieving articles from page 1111
# Retrieving articles from page 1112
# Retrieving articles from page 1113
# Retrieving articles from page 1114
# Retrieving articles from page 1115
# Retrieving articles from page 1116
# Retrieving articles from page 1117
# Retrieving articles from page 1118
# Retrieving articles from page 1119
# Retrieving articles from page 1120
# Retrieving articles from page 1121
# Retrieving articles from page 1122
# Retrieving articles from page 1123
# Retrieving articles from page 1124
# Retrieving articles from page 1125
# Retrieving articles from page 1126
# Retrieving articles from page 1127
# Retrieving articles from page 1128
# Retrieving articles from page 1129
# Retrieving articles from page 1130
# Retrieving articles from page 1131
# Retrieving articles from page 1132
# Retrieving articles from page 1133
# Retrieving articles from page 1134
# Retrieving articles from page 1135
# Retrieving articles from page 1136
# Retrieving articles from page 1137
# Retrieving articles from page 1138
# Retrieving articles from page 1139
# Retrieving articles from page 1140
# Retrieving articles from page 1141
# Retrieving articles from page 1142
# Retrieving articles from page 1143
# Retrieving articles from page 1144
# Retrieving articles from page 1145
# Retrieving articles from page 1146
# Retrieving articles from page 1147
# Retrieving articles from page 1148
# Retrieving articles from page 1149
# Retrieving articles from page 1150
# Retrieving articles from page 1151
# Retrieving articles from page 1152
# Retrieving articles from page 1153
# Retrieving articles from page 1154
# Retrieving articles from page 1155
# Retrieving articles from page 1156
# Retrieving articles from page 1157
# Retrieving articles from page 1158
# Retrieving articles from page 1159
# Retrieving articles from page 1160
# Retrieving articles from page 1161
# Retrieving articles from page 1162
# Retrieving articles from page 1163
# Retrieving articles from page 1164
# Retrieving articles from page 1165
# Retrieving articles from page 1166
# Retrieving articles from page 1167
# Retrieving articles from page 1168
# Retrieving articles from page 1169
# Retrieving articles from page 1170
# Retrieving articles from page 1171
# Retrieving articles from page 1172
# Retrieving articles from page 1173
# Retrieving articles from page 1174
# Retrieving articles from page 1175
# Retrieving articles from page 1176
# Retrieving articles from page 1177
# Retrieving articles from page 1178
# Retrieving articles from page 1179
# Retrieving articles from page 1180
# Retrieving articles from page 1181
# Retrieving articles from page 1182
# Retrieving articles from page 1183
# Retrieving articles from page 1184
# Retrieving articles from page 1185
# Retrieving articles from page 1186
# Retrieving articles from page 1187
# Retrieving articles from page 1188
# Retrieving articles from page 1189
# Retrieving articles from page 1190
# Retrieving articles from page 1191
# Retrieving articles from page 1192
# Retrieving articles from page 1193
# Retrieving articles from page 1194
# Retrieving articles from page 1195
# Retrieving articles from page 1196
# Retrieving articles from page 1197
# Retrieving articles from page 1198
# Retrieving articles from page 1199
# Retrieving articles from page 1200
# Retrieving articles from page 1201
# Retrieving articles from page 1202
# Retrieving articles from page 1203
# Retrieving articles from page 1204
# Retrieving articles from page 1205
# Retrieving articles from page 1206
# Retrieving articles from page 1207
# Retrieving articles from page 1208
# Retrieving articles from page 1209
# Retrieving articles from page 1210
# Retrieving articles from page 1211
# Retrieving articles from page 1212
# Retrieving articles from page 1213
# Retrieving articles from page 1214
# Retrieving articles from page 1215
# Retrieving articles from page 1216
# Retrieving articles from page 1217
# Retrieving articles from page 1218
# Retrieving articles from page 1219
# Retrieving articles from page 1220
# Retrieving articles from page 1221
# Retrieving articles from page 1222
# Retrieving articles from page 1223
# Retrieving articles from page 1224
# Retrieving articles from page 1225
# Retrieving articles from page 1226
# Retrieving articles from page 1227
# Retrieving articles from page 1228
# Retrieving articles from page 1229
# Retrieving articles from page 1230
# Retrieving articles from page 1231
# Retrieving articles from page 1232
# Retrieving articles from page 1233
# Retrieving articles from page 1234
# Retrieving articles from page 1235
# Retrieving articles from page 1236
# Retrieving articles from page 1237
# Retrieving articles from page 1238
# Retrieving articles from page 1239
# Retrieving articles from page 1240
# Retrieving articles from page 1241
# Retrieving articles from page 1242
# Retrieving articles from page 1243
# Retrieving articles from page 1244
# Retrieving articles from page 1245
# Retrieving articles from page 1246
# Retrieving articles from page 1247
# Retrieving articles from page 1248
# Retrieving articles from page 1249
# Retrieving articles from page 1250
# Retrieving articles from page 1251
# Retrieving articles from page 1252
# Retrieving articles from page 1253
# Retrieving articles from page 1254
# Retrieving articles from page 1255
# Retrieving articles from page 1256
# Retrieving articles from page 1257
# Retrieving articles from page 1258
# Retrieving articles from page 1259
# Retrieving articles from page 1260
# Retrieving articles from page 1261
# Retrieving articles from page 1262
# Retrieving articles from page 1263
# Retrieving articles from page 1264
# Retrieving articles from page 1265
# Retrieving articles from page 1266
# Retrieving articles from page 1267
# Retrieving articles from page 1268
# Retrieving articles from page 1269
# Retrieving articles from page 1270
# Retrieving articles from page 1271
# Retrieving articles from page 1272
# Retrieving articles from page 1273
# Retrieving articles from page 1274
# Retrieving articles from page 1275
# Retrieving articles from page 1276
# Retrieving articles from page 1277
# Retrieving articles from page 1278
# Retrieving articles from page 1279
# Retrieving articles from page 1280
# Retrieving articles from page 1281
# Retrieving articles from page 1282
# Retrieving articles from page 1283
# Retrieving articles from page 1284
# Retrieving articles from page 1285
# Retrieving articles from page 1286
# Retrieving articles from page 1287
# Retrieving articles from page 1288
# Retrieving articles from page 1289
# Retrieving articles from page 1290
# Retrieving articles from page 1291
# Retrieving articles from page 1292
# Retrieving articles from page 1293
# Retrieving articles from page 1294
# Retrieving articles from page 1295
# Retrieving articles from page 1296
# Retrieving articles from page 1297
# Retrieving articles from page 1298
# Retrieving articles from page 1299
# Retrieving articles from page 1300
# Retrieving articles from page 1301
# Retrieving articles from page 1302
# Retrieving articles from page 1303
# Retrieving articles from page 1304
# Retrieving articles from page 1305
# Retrieving articles from page 1306
# Retrieving articles from page 1307
# Retrieving articles from page 1308
# Retrieving articles from page 1309
# Retrieving articles from page 1310
# Retrieving articles from page 1311
# Retrieving articles from page 1312
# Retrieving articles from page 1313
# Retrieving articles from page 1314
# Retrieving articles from page 1315
# Retrieving articles from page 1316
# Retrieving articles from page 1317
# Retrieving articles from page 1318
# Retrieving articles from page 1319
# Retrieving articles from page 1320
# Retrieving articles from page 1321
# Retrieving articles from page 1322
# Retrieving articles from page 1323
# Retrieving articles from page 1324
# Retrieving articles from page 1325
# Retrieving articles from page 1326
# Retrieving articles from page 1327
# Retrieving articles from page 1328
# Retrieving articles from page 1329
# Retrieving articles from page 1330
# Retrieving articles from page 1331
# Retrieving articles from page 1332
# Retrieving articles from page 1333
# Retrieving articles from page 1334
# Retrieving articles from page 1335
# Retrieving articles from page 1336
# Retrieving articles from page 1337
# Retrieving articles from page 1338
# Retrieving articles from page 1339
# Retrieving articles from page 1340
# Retrieving articles from page 1341
# Retrieving articles from page 1342
# Retrieving articles from page 1343
# Retrieving articles from page 1344
# Retrieving articles from page 1345
# Retrieving articles from page 1346
# Retrieving articles from page 1347
# Retrieving articles from page 1348
# Retrieving articles from page 1349
# Retrieving articles from page 1350
# Retrieving articles from page 1351
# Retrieving articles from page 1352
# Retrieving articles from page 1353
# Retrieving articles from page 1354
# Retrieving articles from page 1355
# Retrieving articles from page 1356
# Retrieving articles from page 1357
# Retrieving articles from page 1358
# Retrieving articles from page 1359
# Retrieving articles from page 1360
# Retrieving articles from page 1361
# Retrieving articles from page 1362
# Retrieving articles from page 1363
# Retrieving articles from page 1364
# Retrieving articles from page 1365
# Retrieving articles from page 1366
# Retrieving articles from page 1367
# Retrieving articles from page 1368
# Retrieving articles from page 1369
# Retrieving articles from page 1370
# Retrieving articles from page 1371
# Retrieving articles from page 1372
# Retrieving articles from page 1373
# Retrieving articles from page 1374
# Retrieving articles from page 1375
# Retrieving articles from page 1376
# Retrieving articles from page 1377
# Retrieving articles from page 1378
# Retrieving articles from page 1379
# Retrieving articles from page 1380
# Retrieving articles from page 1381
# Retrieving articles from page 1382
# Retrieving articles from page 1383
# Retrieving articles from page 1384
# Retrieving articles from page 1385
# Retrieving articles from page 1386
# Retrieving articles from page 1387
# Retrieving articles from page 1388
# Retrieving articles from page 1389
# Retrieving articles from page 1390
# Retrieving articles from page 1391
# Retrieving articles from page 1392
# Retrieving articles from page 1393
# Retrieving articles from page 1394
# Retrieving articles from page 1395
# Retrieving articles from page 1396
# Retrieving articles from page 1397
# Retrieving articles from page 1398
# Retrieving articles from page 1399
# Retrieving articles from page 1400
# Retrieving articles from page 1401
# Retrieving articles from page 1402
# ...
# Retrieving articles from page 2478
# Retrieving articles from page 2479
# Retrieving articles from page 2480
# Retrieving articles from page 2481
# Retrieving articles from page 2482
# Retrieving articles from page 2483
# Retrieving articles from page 2484
# Retrieving articles from page 2485
# Retrieving articles from page 2486
# Retrieving articles from page 2487
# Retrieving articles from page 2488
# Retrieving articles from page 2489
# Retrieving articles from page 2490
# Retrieving articles from page 2491
# Retrieving articles from page 2492
# Retrieving articles from page 2493
# Retrieving articles from page 2494
# Retrieving articles from page 2495
# Retrieving articles from page 2496
# Retrieving articles from page 2497
# Retrieving articles from page 2498
# Retrieving articles from page 2499
# Retrieving articles from page 2500
# Retrieving articles from page 2501
# Retrieving articles from page 2502
# Retrieving articles from page 2503
# Retrieving articles from page 2504
# Retrieving articles from page 2505
# Retrieving articles from page 2506
# Retrieving articles from page 2507
# Retrieving articles from page 2508
# Retrieving articles from page 2509
# Retrieving articles from page 2510
# Retrieving articles from page 2511
# Retrieving articles from page 2512
# Retrieving articles from page 2513
# Retrieving articles from page 2514
# Retrieving articles from page 2515
# Retrieving articles from page 2516
# Retrieving articles from page 2517
# Retrieving articles from page 2518
# Retrieving articles from page 2519
# Retrieving articles from page 2520
# Retrieving articles from page 2521
# Retrieving articles from page 2522
# Retrieving articles from page 2523
# Retrieving articles from page 2524
# Retrieving articles from page 2525
# Retrieving articles from page 2526
# Retrieving articles from page 2527
# Retrieving articles from page 2528
# Retrieving articles from page 2529
# Retrieving articles from page 2530
# Retrieving articles from page 2531
# Retrieving articles from page 2532
# Retrieving articles from page 2533
# Retrieving articles from page 2534
# Retrieving articles from page 2535
# Retrieving articles from page 2536
# Retrieving articles from page 2537
# Retrieving articles from page 2538
# Retrieving articles from page 2539
# Retrieving articles from page 2540
# Retrieving articles from page 2541
# Retrieving articles from page 2542
# Retrieving articles from page 2543
# Retrieving articles from page 2544
# Retrieving articles from page 2545
# Retrieving articles from page 2546
# Retrieving articles from page 2547
# Retrieving articles from page 2548
# Retrieving articles from page 2549
# Retrieving articles from page 2550
# Retrieving articles from page 2551
# Retrieving articles from page 2552
# Retrieving articles from page 2553
# Retrieving articles from page 2554
# Retrieving articles from page 2555
# Retrieving articles from page 2556
# Retrieving articles from page 2557
# Retrieving articles from page 2558
# Retrieving articles from page 2559
# Retrieving articles from page 2560
# Retrieving articles from page 2561
# Retrieving articles from page 2562
# Retrieving articles from page 2563
# Retrieving articles from page 2564
# Retrieving articles from page 2565
# Retrieving articles from page 2566
# Retrieving articles from page 2567
# Retrieving articles from page 2568
# Retrieving articles from page 2569
# Retrieving articles from page 2570
# Retrieving articles from page 2571
# Retrieving articles from page 2572
# Retrieving articles from page 2573
# Retrieving articles from page 2574
# Retrieving articles from page 2575
# Retrieving articles from page 2576
# Retrieving articles from page 2577
# Retrieving articles from page 2578
# Retrieving articles from page 2579
# Retrieving articles from page 2580
# Retrieving articles from page 2581
# Retrieving articles from page 2582
# Retrieving articles from page 2583
# Retrieving articles from page 2584
# Retrieving articles from page 2585
# Retrieving articles from page 2586
# Retrieving articles from page 2587
# Retrieving articles from page 2588
# Retrieving articles from page 2589
# Retrieving articles from page 2590
# Retrieving articles from page 2591
# Retrieving articles from page 2592
# Retrieving articles from page 2593
# Retrieving articles from page 2594
# Retrieving articles from page 2595
# Retrieving articles from page 2596
# Retrieving articles from page 2597
# Retrieving articles from page 2598
# Retrieving articles from page 2599
# Retrieving articles from page 2600
# Retrieving articles from page 2601
# Retrieving articles from page 2602
# Retrieving articles from page 2603
# Retrieving articles from page 2604
# Retrieving articles from page 2605
# Retrieving articles from page 2606
# Retrieving articles from page 2607
# Retrieving articles from page 2608
# Retrieving articles from page 2609
# Retrieving articles from page 2610
# Retrieving articles from page 2611
# Retrieving articles from page 2612
# Retrieving articles from page 2613
# Retrieving articles from page 2614
# Retrieving articles from page 2615
# Retrieving articles from page 2616
# Retrieving articles from page 2617
# Retrieving articles from page 2618
# Retrieving articles from page 2619
# Retrieving articles from page 2620
# Retrieving articles from page 2621
# Retrieving articles from page 2622
# Retrieving articles from page 2623
# Retrieving articles from page 2624
# Retrieving articles from page 2625
# Retrieving articles from page 2626
# Retrieving articles from page 2627
# Retrieving articles from page 2628
# Retrieving articles from page 2629
# Retrieving articles from page 2630
# Retrieving articles from page 2631
# Retrieving articles from page 2632
# Retrieving articles from page 2633
# Retrieving articles from page 2634
# Retrieving articles from page 2635
# Retrieving articles from page 2636
# Retrieving articles from page 2637
# Retrieving articles from page 2638
# Retrieving articles from page 2639
# Retrieving articles from page 2640
# Retrieving articles from page 2641
# Retrieving articles from page 2642
# Retrieving articles from page 2643
# Retrieving articles from page 2644
# Retrieving articles from page 2645
# Retrieving articles from page 2646
# Retrieving articles from page 2647
# Retrieving articles from page 2648
# Retrieving articles from page 2649
# Retrieving articles from page 2650
# Retrieving articles from page 2651
# Retrieving articles from page 2652
# Retrieving articles from page 2653
# Retrieving articles from page 2654
# Retrieving articles from page 2655
# Retrieving articles from page 2656
# Retrieving articles from page 2657
# Retrieving articles from page 2658
# Retrieving articles from page 2659
# Retrieving articles from page 2660
# Retrieving articles from page 2661
# Retrieving articles from page 2662
# Retrieving articles from page 2663
# Retrieving articles from page 2664
# Retrieving articles from page 2665
# Retrieving articles from page 2666
# Retrieving articles from page 2667
# Retrieving articles from page 2668
# Retrieving articles from page 2669
# Retrieving articles from page 2670
# Retrieving articles from page 2671
# Retrieving articles from page 2672
# Retrieving articles from page 2673
# Retrieving articles from page 2674
# Retrieving articles from page 2675
# Retrieving articles from page 2676
# Retrieving articles from page 2677
# Retrieving articles from page 2678
# Retrieving articles from page 2679
# Retrieving articles from page 2680
# Retrieving articles from page 2681
# Retrieving articles from page 2682
# Retrieving articles from page 2683
# Retrieving articles from page 2684
# Retrieving articles from page 2685
# Retrieving articles from page 2686
# Retrieving articles from page 2687
# Retrieving articles from page 2688
# Retrieving articles from page 2689
# Retrieving articles from page 2690
# Retrieving articles from page 2691
# Retrieving articles from page 2692
# Retrieving articles from page 2693
# Retrieving articles from page 2694
# Retrieving articles from page 2695
# Retrieving articles from page 2696
# Retrieving articles from page 2697
# Retrieving articles from page 2698
# Retrieving articles from page 2699
# Retrieving articles from page 2700
# Retrieving articles from page 2701
# Retrieving articles from page 2702
# Retrieving articles from page 2703
# Retrieving articles from page 2704
# Retrieving articles from page 2705
# Retrieving articles from page 2706
# Retrieving articles from page 2707
# Retrieving articles from page 2708
# Retrieving articles from page 2709
# Retrieving articles from page 2710
# Retrieving articles from page 2711
# Retrieving articles from page 2712
# Retrieving articles from page 2713
# Retrieving articles from page 2714
# Retrieving articles from page 2715
# Retrieving articles from page 2716
# Retrieving articles from page 2717
# Retrieving articles from page 2718
# Retrieving articles from page 2719
# Retrieving articles from page 2720
# Retrieving articles from page 2721
# Retrieving articles from page 2722
# Retrieving articles from page 2723
# Retrieving articles from page 2724
# Retrieving articles from page 2725
# Retrieving articles from page 2726
# Retrieving articles from page 2727
# Retrieving articles from page 2728
# Retrieving articles from page 2729
# Retrieving articles from page 2730
# Retrieving articles from page 2731
# Retrieving articles from page 2732
# Retrieving articles from page 2733
# Retrieving articles from page 2734
# Retrieving articles from page 2735
# Retrieving articles from page 2736
# Retrieving articles from page 2737
# Retrieving articles from page 2738
# Retrieving articles from page 2739
# Retrieving articles from page 2740
# Retrieving articles from page 2741
# Retrieving articles from page 2742
# Retrieving articles from page 2743
# Retrieving articles from page 2744
# Retrieving articles from page 2745
# Retrieving articles from page 2746
# Retrieving articles from page 2747
# Retrieving articles from page 2748
# Retrieving articles from page 2749
# Retrieving articles from page 2750
# Retrieving articles from page 2751
# Retrieving articles from page 2752
# Retrieving articles from page 2753
# Retrieving articles from page 2754
# Retrieving articles from page 2755
# Retrieving articles from page 2756
# Retrieving articles from page 2757
# Retrieving articles from page 2758
# Retrieving articles from page 2759
# Retrieving articles from page 2760
# Retrieving articles from page 2761
# Retrieving articles from page 2762
# Retrieving articles from page 2763
# Retrieving articles from page 2764
# Retrieving articles from page 2765
# Retrieving articles from page 2766
# Retrieving articles from page 2767
# Retrieving articles from page 2768
# Retrieving articles from page 2769
# Retrieving articles from page 2770
# Retrieving articles from page 2771
# Retrieving articles from page 2772
# Retrieving articles from page 2773
# Retrieving articles from page 2774
# Retrieving articles from page 2775
# Retrieving articles from page 2776
# Retrieving articles from page 2777
# Retrieving articles from page 2778
# Retrieving articles from page 2779
# Retrieving articles from page 2780
# Retrieving articles from page 2781
# Retrieving articles from page 2782
# Retrieving articles from page 2783
# Retrieving articles from page 2784
# Retrieving articles from page 2785
# Retrieving articles from page 2786
# Retrieving articles from page 2787
# Retrieving articles from page 2788
# Retrieving articles from page 2789
# Retrieving articles from page 2790
# Retrieving articles from page 2791
# Retrieving articles from page 2792
# Retrieving articles from page 2793
# Retrieving articles from page 2794
# Retrieving articles from page 2795
# Retrieving articles from page 2796
# Retrieving articles from page 2797
# Retrieving articles from page 2798
# Retrieving articles from page 2799
# Retrieving articles from page 2800
# Retrieving articles from page 2801
# Retrieving articles from page 2802
# Retrieving articles from page 2803
# Retrieving articles from page 2804
# Retrieving articles from page 2805
# Retrieving articles from page 2806
# Retrieving articles from page 2807
# Retrieving articles from page 2808
# Retrieving articles from page 2809
# Retrieving articles from page 2810
# Retrieving articles from page 2811
# Retrieving articles from page 2812
# Retrieving articles from page 2813
# Retrieving articles from page 2814
# Retrieving articles from page 2815
# Retrieving articles from page 2816
# Retrieving articles from page 2817
# Retrieving articles from page 2818
# Retrieving articles from page 2819
# Retrieving articles from page 2820
# Retrieving articles from page 2821
# Retrieving articles from page 2822
# Retrieving articles from page 2823
# Retrieving articles from page 2824
# Retrieving articles from page 2825
# Retrieving articles from page 2826
# Retrieving articles from page 2827
# Retrieving articles from page 2828
# Retrieving articles from page 2829
# Retrieving articles from page 2830
# Retrieving articles from page 2831
# Retrieving articles from page 2832
# Retrieving articles from page 2833
# Retrieving articles from page 2834
# Retrieving articles from page 2835
# Retrieving articles from page 2836
# Retrieving articles from page 2837
# Retrieving articles from page 2838
# Retrieving articles from page 2839
# Retrieving articles from page 2840
# Retrieving articles from page 2841
# Retrieving articles from page 2842
# Retrieving articles from page 2843
# Retrieving articles from page 2844
# Retrieving articles from page 2845
# Retrieving articles from page 2846
# Retrieving articles from page 2847
# Retrieving articles from page 2848
# Retrieving articles from page 2849
# Retrieving articles from page 2850
# Retrieving articles from page 2851
# Retrieving articles from page 2852
# Retrieving articles from page 2853
# Retrieving articles from page 2854
# Retrieving articles from page 2855
# Retrieving articles from page 2856
# Retrieving articles from page 2857
# Retrieving articles from page 2858
# Retrieving articles from page 2859
# Retrieving articles from page 2860
# Retrieving articles from page 2861
# Retrieving articles from page 2862
# Retrieving articles from page 2863
# Retrieving articles from page 2864
# Retrieving articles from page 2865
# Retrieving articles from page 2866
# Retrieving articles from page 2867
# Retrieving articles from page 2868
# Retrieving articles from page 2869
# Retrieving articles from page 2870
# Retrieving articles from page 2871
# Retrieving articles from page 2872
# Retrieving articles from page 2873
# Retrieving articles from page 2874
# Retrieving articles from page 2875
# Retrieving articles from page 2876
# Retrieving articles from page 2877
# Retrieving articles from page 2878
# Retrieving articles from page 2879
# Retrieving articles from page 2880
# Retrieving articles from page 2881
# Retrieving articles from page 2882
# Retrieving articles from page 2883
# Retrieving articles from page 2884
# Retrieving articles from page 2885
# Retrieving articles from page 2886
# Retrieving articles from page 2887
# Retrieving articles from page 2888
# Retrieving articles from page 2889
# Retrieving articles from page 2890
# Retrieving articles from page 2891
# Retrieving articles from page 2892
# Retrieving articles from page 2893
# Retrieving articles from page 2894
# Retrieving articles from page 2895
# Retrieving articles from page 2896
# Retrieving articles from page 2897
# Retrieving articles from page 2898
# Retrieving articles from page 2899
# Retrieving articles from page 2900
# Retrieving articles from page 2901
# Retrieving articles from page 2902
# Retrieving articles from page 2903
# Retrieving articles from page 2904
# Retrieving articles from page 2905
# Retrieving articles from page 2906
# Retrieving articles from page 2907
# Retrieving articles from page 2908
# Retrieving articles from page 2909
# Retrieving articles from page 2910
# Retrieving articles from page 2911
# Retrieving articles from page 2912
# Retrieving articles from page 2913
# Retrieving articles from page 2914
# Retrieving articles from page 2915
# Retrieving articles from page 2916
# Retrieving articles from page 2917
# Retrieving articles from page 2918
# Retrieving articles from page 2919
# Retrieving articles from page 2920
# Retrieving articles from page 2921
# Retrieving articles from page 2922
# Retrieving articles from page 2923
# Retrieving articles from page 2924
# Retrieving articles from page 2925
# Retrieving articles from page 2926
# Retrieving articles from page 2927
# Retrieving articles from page 2928
# Retrieving articles from page 2929
# Retrieving articles from page 2930
# Retrieving articles from page 2931
# Retrieving articles from page 2932
# Retrieving articles from page 2933
# Retrieving articles from page 2934

# %%
# find index of journal
i = 0
for journal in journals:
    if journal[0] == 'Observatorio (OBS*)':
        print(i)
    i +=1
# Out:
# 7441

# %%
len(journals)
# Out:
# 10352
